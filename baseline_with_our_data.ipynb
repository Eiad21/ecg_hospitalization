# %%
import numpy as np
import pandas as pd
from scipy.stats import skew, kurtosis
from scipy.signal import welch
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
import pickle

# %%
# Open the file in binary read mode ('rb') to unpickle the data
with open('batch_of_data.pickle', 'rb') as file:
    loaded_data = pickle.load(file)

# %%
loaded_data
# Out:
# [{'I': array([-18, -23, -23, ..., -31, -33, -31], dtype=int16),
#   'II': array([-21, -25, -22, ...,  10,  11,  12], dtype=int16),
#   'V1': array([ 5,  7,  7, ..., 31, 32, 31], dtype=int16),
#   'V2': array([-47, -38, -30, ...,  24,  26,  25], dtype=int16),
#   'V3': array([9, 9, 9, ..., 2, 3, 2], dtype=int16),
#   'V4': array([ -2,   0,   1, ..., -30, -28, -30], dtype=int16),
#   'V5': array([-54, -49, -46, ..., -32, -30, -33], dtype=int16),
#   'V6': array([  -1,    2,    3, ..., -131, -129, -132], dtype=int16)},
#  {'I': array([-46, -46, -46, ...,  -8,  -5,  -4], dtype=int16),
#   'II': array([-34, -34, -34, ...,  84,  86,  86], dtype=int16),
#   'V1': array([-50, -50, -50, ..., -80, -80, -85], dtype=int16),
#   'V2': array([40, 40, 40, ..., 80, 73, 70], dtype=int16),
#   'V3': array([-4, -4, -4, ..., 42, 36, 33], dtype=int16),
#   'V4': array([-8, -8, -8, ..., 28, 23, 21], dtype=int16),
#   'V5': array([-12, -12, -12, ..., -73, -75, -77], dtype=int16),
#   'V6': array([114, 114, 114, ..., 104, 106, 108], dtype=int16)},
#  {'I': array([-18, -18, -18, ...,  -1,   1,   5], dtype=int16),
#   'II': array([-10, -10, -10, ..., -20, -26, -35], dtype=int16),
#   'V1': array([-12, -12, -12, ...,   5,   7,   8], dtype=int16),
#   'V2': array([ -8,  -8,  -8, ..., -31, -29, -28], dtype=int16),
#   'V3': array([-14, -14, -14, ..., -71, -69, -70], dtype=int16),
#   'V4': array([-16, -16, -16, ..., -26, -24, -24], dtype=int16),
#   'V5': array([ -12,  -12,  -12, ..., -109, -109, -108], dtype=int16),
#   'V6': array([-30, -30, -30, ..., -77, -75, -73], dtype=int16)},
#  {'I': array([ 12,  12,  12, ..., 111, 108, 105], dtype=int16),
#   'II': array([-8, -8, -8, ..., 20, 26, 32], dtype=int16),
#   'V1': array([ -44,  -44,  -44, ..., -289, -276, -263], dtype=int16),
#   'V2': array([ -18,  -18,  -18, ..., -392, -376, -360], dtype=int16),
#   'V3': array([ -48,  -48,  -48, ..., -394, -380, -366], dtype=int16),
#   'V4': array([ 20,  20,  20, ..., -37, -28, -19], dtype=int16),
#   'V5': array([  96,   96,   96, ..., -205, -198, -191], dtype=int16),
#   'V6': array([280, 280, 280, ...,  -2,   4,  10], dtype=int16)},
#  {'I': array([  2,   2,   2, ..., -34, -34, -34], dtype=int16),
#   'II': array([-50, -50, -50, ..., -12, -13, -14], dtype=int16),
#   'V1': array([ -38,  -38,  -38, ..., -128, -128, -128], dtype=int16),
#   'V2': array([-26, -26, -26, ..., -24, -24, -24], dtype=int16),
#   'V3': array([-48, -48, -48, ..., -64, -64, -64], dtype=int16),
#   'V4': array([-44, -44, -44, ..., -64, -64, -64], dtype=int16),
#   'V5': array([ -38,  -38,  -38, ..., -116, -116, -116], dtype=int16),
#   'V6': array([14, 14, 14, ..., 74, 73, 72], dtype=int16)},
#  {'I': array([-143, -144, -146, ...,  -88,  -87,  -88], dtype=int16),
#   'II': array([ -9, -11, -12, ..., -11,  -3,  -7], dtype=int16),
#   'V1': array([70, 69, 69, ..., 43, 42, 44], dtype=int16),
#   'V2': array([52, 52, 53, ..., 50, 50, 51], dtype=int16),
#   'V3': array([41, 41, 42, ..., 83, 82, 83], dtype=int16),
#   'V4': array([37, 38, 38, ..., 70, 71, 71], dtype=int16),
#   'V5': array([36, 36, 37, ..., 14, 16, 15], dtype=int16),
#   'V6': array([ 35,  35,  35, ..., -11, -11, -13], dtype=int16)},
#  {'I': array([ 36,  36,  36, ..., -52, -51, -53], dtype=int16),
#   'II': array([-76, -76, -76, ..., -15, -14, -14], dtype=int16),
#   'V1': array([-20, -20, -20, ...,   4,   5,   5], dtype=int16),
#   'V2': array([-40, -40, -40, ...,   8,   8,   8], dtype=int16),
#   'V3': array([-52, -52, -52, ..., -39, -39, -38], dtype=int16),
#   'V4': array([ -44,  -44,  -44, ..., -116, -115, -112], dtype=int16),
#   'V5': array([  28,   28,   28, ..., -159, -159, -157], dtype=int16),
#   'V6': array([ -22,  -22,  -22, ..., -138, -139, -138], dtype=int16)},
#  {'I': array([-6, -6, -6, ..., 13,  8,  3], dtype=int16),
#   'II': array([10, 10, 10, ...,  5, 10, 15], dtype=int16),
#   'V1': array([  8,   8,   8, ..., -14, -14, -14], dtype=int16),
#   'V2': array([ -6,  -6,  -6, ..., -42, -42, -42], dtype=int16),
#   'V3': array([-20, -20, -20, ..., -63, -62, -61], dtype=int16),
#   'V4': array([ 188,  188,  188, ..., -267, -270, -273], dtype=int16),
#   'V5': array([ 610,  610,  610, ..., -104, -106, -108], dtype=int16),
#   'V6': array([-7824, -7824, -7824, ...,  -187,  -190,  -193], dtype=int16)},
#  {'I': array([-16, -11, -10, ...,  39,  37,  32], dtype=int16),
#   'II': array([49, 54, 55, ..., 18, 24, 22], dtype=int16),
#   'V1': array([-101, -102, -102, ...,    6,    5,    7], dtype=int16),
#   'V2': array([16, 16, 16, ..., 12, 11, 12], dtype=int16),
#   'V3': array([108, 108, 108, ...,  39,  37,  39], dtype=int16),
#   'V4': array([19, 19, 21, ..., -7, -8, -8], dtype=int16),
#   'V5': array([  3,   3,   6, ..., -24, -26, -27], dtype=int16),
#   'V6': array([-28, -27, -25, ..., -17, -19, -19], dtype=int16)},
#  {'I': array([-14, -14, -14, ...,  11,  15,  14], dtype=int16),
#   'II': array([ -6,  -6,  -6, ..., -20, -16, -20], dtype=int16),
#   'V1': array([ -96,  -96,  -96, ..., -164, -162, -161], dtype=int16),
#   'V2': array([-20, -20, -20, ..., -91, -91, -87], dtype=int16),
#   'V3': array([-162, -162, -162, ...,    7,    9,   15], dtype=int16),
#   'V4': array([-466, -466, -466, ..., -296, -294, -287], dtype=int16),
#   'V5': array([-160, -160, -160, ..., -165, -162, -160], dtype=int16),
#   'V6': array([  10,   10,   10, ..., -112, -108, -103], dtype=int16)}]

# %%
data = []
for patient in loaded_data:
    new_patient_format = np.array(list(patient.values()))
    data.append(new_patient_format)
    print(len(new_patient_format[7]))
# Out:
# 5000
# 5000
# 5000
# 5000
# 5000
# 5000
# 5000
# 5000
# 5000
# 5000

# %%
data = np.array(data)

# %%
data
# Out:
# array([[[  -18,   -23,   -23, ...,   -31,   -33,   -31],
#         [  -21,   -25,   -22, ...,    10,    11,    12],
#         [    5,     7,     7, ...,    31,    32,    31],
#         ...,
#         [   -2,     0,     1, ...,   -30,   -28,   -30],
#         [  -54,   -49,   -46, ...,   -32,   -30,   -33],
#         [   -1,     2,     3, ...,  -131,  -129,  -132]],
#
#        [[  -46,   -46,   -46, ...,    -8,    -5,    -4],
#         [  -34,   -34,   -34, ...,    84,    86,    86],
#         [  -50,   -50,   -50, ...,   -80,   -80,   -85],
#         ...,
#         [   -8,    -8,    -8, ...,    28,    23,    21],
#         [  -12,   -12,   -12, ...,   -73,   -75,   -77],
#         [  114,   114,   114, ...,   104,   106,   108]],
#
#        [[  -18,   -18,   -18, ...,    -1,     1,     5],
#         [  -10,   -10,   -10, ...,   -20,   -26,   -35],
#         [  -12,   -12,   -12, ...,     5,     7,     8],
#         ...,
#         [  -16,   -16,   -16, ...,   -26,   -24,   -24],
#         [  -12,   -12,   -12, ...,  -109,  -109,  -108],
#         [  -30,   -30,   -30, ...,   -77,   -75,   -73]],
#
#        ...,
#
#        [[   -6,    -6,    -6, ...,    13,     8,     3],
#         [   10,    10,    10, ...,     5,    10,    15],
#         [    8,     8,     8, ...,   -14,   -14,   -14],
#         ...,
#         [  188,   188,   188, ...,  -267,  -270,  -273],
#         [  610,   610,   610, ...,  -104,  -106,  -108],
#         [-7824, -7824, -7824, ...,  -187,  -190,  -193]],
#
#        [[  -16,   -11,   -10, ...,    39,    37,    32],
#         [   49,    54,    55, ...,    18,    24,    22],
#         [ -101,  -102,  -102, ...,     6,     5,     7],
#         ...,
#         [   19,    19,    21, ...,    -7,    -8,    -8],
#         [    3,     3,     6, ...,   -24,   -26,   -27],
#         [  -28,   -27,   -25, ...,   -17,   -19,   -19]],
#
#        [[  -14,   -14,   -14, ...,    11,    15,    14],
#         [   -6,    -6,    -6, ...,   -20,   -16,   -20],
#         [  -96,   -96,   -96, ...,  -164,  -162,  -161],
#         ...,
#         [ -466,  -466,  -466, ...,  -296,  -294,  -287],
#         [ -160,  -160,  -160, ...,  -165,  -162,  -160],
#         [   10,    10,    10, ...,  -112,  -108,  -103]]], dtype=int16)

# %%
# Function to extract features from each lead
def extract_features(lead):
    mean_value = np.mean(lead)
    std_dev = np.std(lead)
    skewness = skew(lead)
    kurt = kurtosis(lead)
    
    # Spectral features using Welch method
    _, psd = welch(lead)
    max_power_freq = np.argmax(psd)
    mean_power = np.mean(psd)
    
    return mean_value, std_dev, skewness, kurt, max_power_freq, mean_power

# %%
ecg_data = data

# %%
# Apply feature extraction to each lead
lead_features = np.apply_along_axis(lambda lead: np.array(extract_features(lead)), axis=2, arr=ecg_data)

# %%
num_leads = 8

# %%
num_samples = 10

# %%
# Create a DataFrame with feature names
feature_names = [f'Lead{i}_{stat}' for i in range(1, num_leads + 1) for stat in ['Mean', 'StdDev', 'Skew', 'Kurt', 'MaxPowerFreq', 'MeanPower']]
ecg_df = pd.DataFrame(lead_features.reshape(num_samples, -1), columns=feature_names)

# %%
# Add the target variable
ecg_df['Severity'] = np.array([0,0,0,2,0,0,0,0,0,0])

# %%
ecg_df
# Out:
#    Lead1_Mean  Lead1_StdDev  Lead1_Skew  Lead1_Kurt  Lead1_MaxPowerFreq  \
# 0     -1.5000     36.049422    2.314799    4.975224                 2.0
# 1     -6.5872     39.197245    2.176368    4.454381                 2.0
# 2      0.8286     28.751105    3.332958   12.369288                 2.0
# 3      8.8842     39.188738    1.969945    5.408691                 2.0
# 4     -3.4822     34.407989    3.142274   10.509170                 2.0
# 5    -43.4668     47.782772    0.746709    0.919928                 1.0
# 6     -4.8628     37.550302    2.943368    9.258202                 2.0
# 7      2.8040     31.411163    3.041112    9.949202                 2.0
# 8      7.6514     33.738498    3.431281   13.120279                 2.0
# 9      4.0280     35.662401    3.036944   10.342252                 2.0
#
#    Lead1_MeanPower  Lead2_Mean  Lead2_StdDev  Lead2_Skew  Lead2_Kurt  ...  \
# 0      2517.791260     -0.2124     32.092885   -1.512631    3.894237  ...
# 1      3532.866943     -3.5318     34.415499   -0.984946    2.578938  ...
# 2      1570.428833     -4.5700     21.160404   -0.312583    8.796732  ...
# 3      2106.440674     -0.6628     44.199017   -0.172189   -0.069797  ...
# 4      2398.953857     -1.2890     23.597387    0.073601    5.539113  ...
# 5      1818.098877    -11.1084     28.829205   -1.109292    3.937247  ...
# 6      2686.497803     -1.6660     29.409870   -1.194493    4.609127  ...
# 7      1793.974487      7.0990     25.867137   -1.084414    4.935357  ...
# 8      2009.421997     19.3980     27.102022   -2.437146   10.232016  ...
# 9      2349.001953     -2.4340     25.299440   -2.249303    8.714789  ...
#
#    Lead7_Kurt  Lead7_MaxPowerFreq  Lead7_MeanPower  Lead8_Mean  Lead8_StdDev  \
# 0    1.397434                 1.0      1963.283081     -5.2038     66.383961
# 1    0.132929                 1.0      3560.788574     -8.0332    151.243856
# 2   10.491898                 2.0      2001.522705     -8.7316     36.603240
# 3    0.246015                 1.0      2411.773438     20.9372    157.659876
# 4    6.671241                 2.0      1495.157349    -24.8848     54.073202
# 5    6.624335                 2.0      1472.199829      7.0670     35.013639
# 6    0.181511                 2.0      2774.627930     -4.4184     62.746399
# 7    9.247506                 1.0      2838.928955    292.7960    819.526973
# 8   20.731822                 2.0      1647.510254    -15.1450     38.187794
# 9    2.963587                 1.0     33805.292969     -4.3528     80.671402
#
#    Lead8_Skew  Lead8_Kurt  Lead8_MaxPowerFreq  Lead8_MeanPower  Severity
# 0    0.411321   -0.258793                 2.0      1314.836914         0
# 1    0.624826    0.040773                 1.0      5510.708496         0
# 2    2.446000   11.352048                 2.0      1928.089478         0
# 3    0.892897    0.857702                 1.0      3726.195801         2
# 4    0.662640    0.551886                 1.0      1655.096558         0
# 5    2.379774    8.364886                 2.0      2005.720337         0
# 6    1.682007    3.577332                 2.0      2740.827148         0
# 7   -1.386061   15.321463                 1.0    172831.984375         0
# 8    1.821300    7.330171                 2.0      1676.395996         0
# 9   -0.264280    1.733284                 1.0      2917.191650         0
#
# [10 rows x 49 columns]

# %%
severity_labels = ecg_df['Severity']

# %%
# Prepare the features and target variable
X = ecg_df.drop(['Severity'], axis=1)
y = ecg_df['Severity']

# %%
X
# Out:
#    Lead1_Mean  Lead1_StdDev  Lead1_Skew  Lead1_Kurt  Lead1_MaxPowerFreq  \
# 0     -1.5000     36.049422    2.314799    4.975224                 2.0
# 1     -6.5872     39.197245    2.176368    4.454381                 2.0
# 2      0.8286     28.751105    3.332958   12.369288                 2.0
# 3      8.8842     39.188738    1.969945    5.408691                 2.0
# 4     -3.4822     34.407989    3.142274   10.509170                 2.0
# 5    -43.4668     47.782772    0.746709    0.919928                 1.0
# 6     -4.8628     37.550302    2.943368    9.258202                 2.0
# 7      2.8040     31.411163    3.041112    9.949202                 2.0
# 8      7.6514     33.738498    3.431281   13.120279                 2.0
# 9      4.0280     35.662401    3.036944   10.342252                 2.0
#
#    Lead1_MeanPower  Lead2_Mean  Lead2_StdDev  Lead2_Skew  Lead2_Kurt  ...  \
# 0      2517.791260     -0.2124     32.092885   -1.512631    3.894237  ...
# 1      3532.866943     -3.5318     34.415499   -0.984946    2.578938  ...
# 2      1570.428833     -4.5700     21.160404   -0.312583    8.796732  ...
# 3      2106.440674     -0.6628     44.199017   -0.172189   -0.069797  ...
# 4      2398.953857     -1.2890     23.597387    0.073601    5.539113  ...
# 5      1818.098877    -11.1084     28.829205   -1.109292    3.937247  ...
# 6      2686.497803     -1.6660     29.409870   -1.194493    4.609127  ...
# 7      1793.974487      7.0990     25.867137   -1.084414    4.935357  ...
# 8      2009.421997     19.3980     27.102022   -2.437146   10.232016  ...
# 9      2349.001953     -2.4340     25.299440   -2.249303    8.714789  ...
#
#    Lead7_Skew  Lead7_Kurt  Lead7_MaxPowerFreq  Lead7_MeanPower  Lead8_Mean  \
# 0   -0.416187    1.397434                 1.0      1963.283081     -5.2038
# 1    0.347672    0.132929                 1.0      3560.788574     -8.0332
# 2    2.137040   10.491898                 2.0      2001.522705     -8.7316
# 3    0.685994    0.246015                 1.0      2411.773438     20.9372
# 4    1.233673    6.671241                 2.0      1495.157349    -24.8848
# 5    2.111958    6.624335                 2.0      1472.199829      7.0670
# 6   -0.497194    0.181511                 2.0      2774.627930     -4.4184
# 7    1.410819    9.247506                 1.0      2838.928955    292.7960
# 8    3.909561   20.731822                 2.0      1647.510254    -15.1450
# 9    1.242876    2.963587                 1.0     33805.292969     -4.3528
#
#    Lead8_StdDev  Lead8_Skew  Lead8_Kurt  Lead8_MaxPowerFreq  Lead8_MeanPower
# 0     66.383961    0.411321   -0.258793                 2.0      1314.836914
# 1    151.243856    0.624826    0.040773                 1.0      5510.708496
# 2     36.603240    2.446000   11.352048                 2.0      1928.089478
# 3    157.659876    0.892897    0.857702                 1.0      3726.195801
# 4     54.073202    0.662640    0.551886                 1.0      1655.096558
# 5     35.013639    2.379774    8.364886                 2.0      2005.720337
# 6     62.746399    1.682007    3.577332                 2.0      2740.827148
# 7    819.526973   -1.386061   15.321463                 1.0    172831.984375
# 8     38.187794    1.821300    7.330171                 2.0      1676.395996
# 9     80.671402   -0.264280    1.733284                 1.0      2917.191650
#
# [10 rows x 48 columns]

# %%
y
# Out:
# 0    1
# 1    1
# 2    0
# 3    0
# 4    0
# 5    1
# 6    0
# 7    0
# 8    1
# 9    0
# Name: Severity, dtype: int32

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
X_train
# Out:
#    Lead1_Mean  Lead1_StdDev  Lead1_Skew  Lead1_Kurt  Lead1_MaxPowerFreq  \
# 1     -6.5872     39.197245    2.176368    4.454381                 2.0
# 5    -43.4668     47.782772    0.746709    0.919928                 1.0
# 0     -1.5000     36.049422    2.314799    4.975224                 2.0
# 7      2.8040     31.411163    3.041112    9.949202                 2.0
# 2      0.8286     28.751105    3.332958   12.369288                 2.0
# 9      4.0280     35.662401    3.036944   10.342252                 2.0
# 4     -3.4822     34.407989    3.142274   10.509170                 2.0
# 3      8.8842     39.188738    1.969945    5.408691                 2.0
# 6     -4.8628     37.550302    2.943368    9.258202                 2.0
#
#    Lead1_MeanPower  Lead2_Mean  Lead2_StdDev  Lead2_Skew  Lead2_Kurt  ...  \
# 1      3532.866943     -3.5318     34.415499   -0.984946    2.578938  ...
# 5      1818.098877    -11.1084     28.829205   -1.109292    3.937247  ...
# 0      2517.791260     -0.2124     32.092885   -1.512631    3.894237  ...
# 7      1793.974487      7.0990     25.867137   -1.084414    4.935357  ...
# 2      1570.428833     -4.5700     21.160404   -0.312583    8.796732  ...
# 9      2349.001953     -2.4340     25.299440   -2.249303    8.714789  ...
# 4      2398.953857     -1.2890     23.597387    0.073601    5.539113  ...
# 3      2106.440674     -0.6628     44.199017   -0.172189   -0.069797  ...
# 6      2686.497803     -1.6660     29.409870   -1.194493    4.609127  ...
#
#    Lead7_Skew  Lead7_Kurt  Lead7_MaxPowerFreq  Lead7_MeanPower  Lead8_Mean  \
# 1    0.347672    0.132929                 1.0      3560.788574     -8.0332
# 5    2.111958    6.624335                 2.0      1472.199829      7.0670
# 0   -0.416187    1.397434                 1.0      1963.283081     -5.2038
# 7    1.410819    9.247506                 1.0      2838.928955    292.7960
# 2    2.137040   10.491898                 2.0      2001.522705     -8.7316
# 9    1.242876    2.963587                 1.0     33805.292969     -4.3528
# 4    1.233673    6.671241                 2.0      1495.157349    -24.8848
# 3    0.685994    0.246015                 1.0      2411.773438     20.9372
# 6   -0.497194    0.181511                 2.0      2774.627930     -4.4184
#
#    Lead8_StdDev  Lead8_Skew  Lead8_Kurt  Lead8_MaxPowerFreq  Lead8_MeanPower
# 1    151.243856    0.624826    0.040773                 1.0      5510.708496
# 5     35.013639    2.379774    8.364886                 2.0      2005.720337
# 0     66.383961    0.411321   -0.258793                 2.0      1314.836914
# 7    819.526973   -1.386061   15.321463                 1.0    172831.984375
# 2     36.603240    2.446000   11.352048                 2.0      1928.089478
# 9     80.671402   -0.264280    1.733284                 1.0      2917.191650
# 4     54.073202    0.662640    0.551886                 1.0      1655.096558
# 3    157.659876    0.892897    0.857702                 1.0      3726.195801
# 6     62.746399    1.682007    3.577332                 2.0      2740.827148
#
# [9 rows x 48 columns]

# %%
y_train
# Out:
# 1    0
# 5    0
# 0    0
# 7    0
# 2    0
# 9    0
# 4    0
# 3    2
# 6    0
# Name: Severity, dtype: int32

# %%
# Train a Random Forest classifier
clf = RandomForestClassifier(random_state=42)
clf.fit(X_train, y_train)
# Out:
# C:\Users\Iskndranii\anaconda3\envs\e_hc_h\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# C:\Users\Iskndranii\anaconda3\envs\e_hc_h\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\Iskndranii\anaconda3\envs\e_hc_h\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\Iskndranii\anaconda3\envs\e_hc_h\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\Iskndranii\anaconda3\envs\e_hc_h\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# RandomForestClassifier(random_state=42)

# %%
# Make predictions on the test set
y_pred = clf.predict(X_test)
# Out:
# C:\Users\Iskndranii\anaconda3\envs\e_hc_h\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# C:\Users\Iskndranii\anaconda3\envs\e_hc_h\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\Iskndranii\anaconda3\envs\e_hc_h\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %%
y_overfit = clf.predict(X_train)
# Out:
# C:\Users\Iskndranii\anaconda3\envs\e_hc_h\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# C:\Users\Iskndranii\anaconda3\envs\e_hc_h\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\Iskndranii\anaconda3\envs\e_hc_h\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %%
# Evaluate the model
accuracy = accuracy_score(y_train, y_overfit)
print(f"Accuracy: {accuracy}")
accuracy2 = accuracy_score(y_test, y_pred)
print(f"Accuracy2: {accuracy2}")
# Out:
# Accuracy: 1.0
# Accuracy2: 1.0
# C:\Users\Iskndranii\anaconda3\envs\e_hc_h\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\Iskndranii\anaconda3\envs\e_hc_h\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\Iskndranii\anaconda3\envs\e_hc_h\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\Iskndranii\anaconda3\envs\e_hc_h\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\Iskndranii\anaconda3\envs\e_hc_h\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\Iskndranii\anaconda3\envs\e_hc_h\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\Iskndranii\anaconda3\envs\e_hc_h\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\Iskndranii\anaconda3\envs\e_hc_h\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\Iskndranii\anaconda3\envs\e_hc_h\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\Iskndranii\anaconda3\envs\e_hc_h\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\Iskndranii\anaconda3\envs\e_hc_h\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\Iskndranii\anaconda3\envs\e_hc_h\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
